# %%
! pip install kafka-python
# Out:
# Requirement already satisfied: kafka-python in /opt/conda/lib/python3.7/site-packages (1.4.6)

# %%
! pip install twint nest_asyncio
# Out:
# Requirement already satisfied: twint in ./src/twint (1.2.3)
# Requirement already satisfied: nest_asyncio in /opt/conda/lib/python3.7/site-packages (1.0.0)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.7/site-packages (from twint) (3.5.4)
# Requirement already satisfied: aiodns in /opt/conda/lib/python3.7/site-packages (from twint) (2.0.0)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.7/site-packages (from twint) (4.7.1)
# Requirement already satisfied: cchardet in /opt/conda/lib/python3.7/site-packages (from twint) (2.1.4)
# Requirement already satisfied: elasticsearch in /opt/conda/lib/python3.7/site-packages (from twint) (7.0.1)
# Requirement already satisfied: pysocks in /opt/conda/lib/python3.7/site-packages (from twint) (1.6.8)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.7/site-packages (from twint) (0.24.2)
# Requirement already satisfied: aiohttp_socks in /opt/conda/lib/python3.7/site-packages (from twint) (0.2.2)
# Requirement already satisfied: schedule in /opt/conda/lib/python3.7/site-packages (from twint) (0.6.0)
# Requirement already satisfied: geopy in /opt/conda/lib/python3.7/site-packages (from twint) (1.19.0)
# Requirement already satisfied: fake-useragent in /opt/conda/lib/python3.7/site-packages (from twint) (0.1.11)
# Requirement already satisfied: async-timeout<4.0,>=3.0 in /opt/conda/lib/python3.7/site-packages (from aiohttp->twint) (3.0.1)
# Requirement already satisfied: chardet<4.0,>=2.0 in /opt/conda/lib/python3.7/site-packages (from aiohttp->twint) (3.0.4)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.7/site-packages (from aiohttp->twint) (19.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.7/site-packages (from aiohttp->twint) (1.3.0)
# Requirement already satisfied: multidict<5.0,>=4.0 in /opt/conda/lib/python3.7/site-packages (from aiohttp->twint) (4.5.2)
# Requirement already satisfied: pycares>=3.0.0 in /opt/conda/lib/python3.7/site-packages (from aiodns->twint) (3.0.0)
# Requirement already satisfied: soupsieve>=1.2 in /opt/conda/lib/python3.7/site-packages (from beautifulsoup4->twint) (1.9)
# Requirement already satisfied: urllib3>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from elasticsearch->twint) (1.24.1)
# Requirement already satisfied: pytz>=2011k in /opt/conda/lib/python3.7/site-packages (from pandas->twint) (2018.9)
# Requirement already satisfied: numpy>=1.12.0 in /opt/conda/lib/python3.7/site-packages (from pandas->twint) (1.15.4)
# Requirement already satisfied: python-dateutil>=2.5.0 in /opt/conda/lib/python3.7/site-packages (from pandas->twint) (2.8.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in /opt/conda/lib/python3.7/site-packages (from geopy->twint) (1.49)
# Requirement already satisfied: idna>=2.0 in /opt/conda/lib/python3.7/site-packages (from yarl<2.0,>=1.0->aiohttp->twint) (2.8)
# Requirement already satisfied: cffi>=1.5.0 in /opt/conda/lib/python3.7/site-packages (from pycares>=3.0.0->aiodns->twint) (1.12.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.7/site-packages (from python-dateutil>=2.5.0->pandas->twint) (1.12.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.7/site-packages (from cffi>=1.5.0->pycares>=3.0.0->aiodns->twint) (2.19)

# %%
import json
import pprint
import twint
import nest_asyncio
nest_asyncio.apply()

from kafka import KafkaConsumer, KafkaProducer

# %%
def publish_message(producer_instance, topic_name, key, value):
    try:
        key_bytes = bytes(key, encoding='utf-8')
        value_bytes = bytes(value, encoding='utf-8')
        producer_instance.send(topic_name, key=key_bytes, value=value_bytes)
        producer_instance.flush()
        print('Message published successfully.')
    except Exception as ex:
        print('Exception in publishing message')
        print(ex)


def connect_kafka_producer(server):
    _producer = None
    try:
        _producer = KafkaProducer(bootstrap_servers=[server], api_version=(0, 10))
    except Exception as ex:
        print('Exception while connecting Kafka')
        print(str(ex))
    finally:
        return _producer

# %%
kafka_broker = 'broker:9093'
kafka_producer = connect_kafka_producer(kafka_broker)

# %%
pp = pprint.PrettyPrinter(indent=4)

# Events on this topic are produced by Neo4j Streams CDC
consumer = KafkaConsumer("users2", 
                         auto_offset_reset='earliest',
                         bootstrap_servers=[kafka_broker], 
                         api_version=(0, 10),                     
                         consumer_timeout_ms=1000,
                        value_deserializer = json.loads)
for msg in consumer:
    pp.pprint(msg.value)
# Out:
# {   'meta': {   'operation': 'deleted',
#                 'source': {'hostname': 'neo4j'},
#                 'timestamp': 1558278302233,
#                 'txEventId': 0,
#                 'txEventsCount': 27,
#                 'txId': 7226,
#                 'username': 'neo4j'},
#     'payload': {   'after': None,
#                    'before': {   'labels': ['User'],
#                                  'properties': {   'bio': 'a geek mother of '
#                                                           'two girls   hold '
#                                                           'aaPhD from '
#                                                           '@INSIGHT_Centre  '
#                                                           'Galway '
#                                                           '@yordangunawan wife '
#                                                           'works @its_campus',
#                                                    'followers': 2570,
#                                                    'following': 197,
#                                                    'id': 13500752,
#                                                    'location': 'Galway, '
#                                                                'Ireland',
#                                                    'name': 'Nur Aini '
#                                                            'Rakhmawati',
#                                                    'tweets': 17830,
#                                                    'username': 'nuraini'}},
#                    'id': '5557',
#                    'type': 'node'},
#     'schema': {'constraints': None, 'properties': []}}
# {   'meta': {   'operation': 'deleted',
#                 'source': {'hostname': 'neo4j'},
#                 'timestamp': 1558278302233,
#                 'txEventId': 10,
#                 'txEventsCount': 27,
#                 'txId': 7226,
#                 'username': 'neo4j'},
#     'payload': {   'after': None,
#                    'before': {   'labels': ['User'],
#                                  'properties': {   'bio': 'Mad about graphs. '
#                                                           'Working on and with '
#                                                           'Neo4j. Write about '
#                                                           'that on '
#                                                           'http://blog.bruggen.com\xa0'
#                                                           '.',
#                                                    'followers': 2010,
#                                                    'following': 1176,
#                                                    'id': 18263413,
#                                                    'location': 'Antwerp',
#                                                    'name': 'Rik Van Bruggen',
#                                                    'tweets': 3402,
#                                                    'username': 'rvanbruggen'}},
#                    'id': '5567',
#                    'type': 'node'},
#     'schema': {'constraints': None, 'properties': []}}
# {   'meta': {   'operation': 'deleted',
#                 'source': {'hostname': 'neo4j'},
#                 'timestamp': 1558278302233,
#                 'txEventId': 11,
#                 'txEventsCount': 27,
#                 'txId': 7226,
#                 'username': 'neo4j'},
#     'payload': {   'after': None,
#                    'before': {   'labels': ['User'],
#                                  'properties': {   'bio': 'The #1 platform for '
#                                                           'connected data. '
#                                                           'Developers start '
#                                                           'here: '
#                                                           'https://neo4j.com/developer/\xa0',
#                                                    'followers': 28692,
#                                                    'following': 7243,
#                                                    'id': 22467617,
#                                                    'location': 'Graphs Are '
#                                                                'Everywhere',
#                                                    'name': 'Neo4j',
#                                                    'tweets': 40050,
#                                                    'username': 'neo4j'}},
#                    'id': '5566',
#                    'type': 'node'},
#     'schema': {'constraints': None, 'properties': []}}
# {   'meta': {   'operation': 'deleted',
#                 'source': {'hostname': 'neo4j'},
#                 'timestamp': 1558278302233,
#                 'txEventId': 13,
#                 'txEventsCount': 27,
#                 'txId': 7226,
#                 'username': 'neo4j'},
#     'payload': {   'after': None,
#                    'before': {   'labels': ['User'],
#                                  'properties': {   'id': 599665849,
#                                                    'username': 'graphconnect'}},
#                    'id': '5537',
#                    'type': 'node'},
#     'schema': {'constraints': None, 'properties': []}}
# {   'meta': {   'operation': 'deleted',
#                 'source': {'hostname': 'neo4j'},
#                 'timestamp': 1558278302233,
#                 'txEventId': 14,
#                 'txEventsCount': 27,
#                 'txId': 7226,
#                 'username': 'neo4j'},
#     'payload': {   'after': None,
#                    'before': {   'labels': ['User'],
#                                  'properties': {   'id': 703296564,
#                                                    'username': 'neo4jfr'}},
#                    'id': '5570',
#                    'type': 'node'},
#     'schema': {'constraints': None, 'properties': []}}
# {   'meta': {   'operation': 'deleted',
#                 'source': {'hostname': 'neo4j'},
#                 'timestamp': 1558278302233,
#                 'txEventId': 15,
#                 'txEventsCount': 27,
#                 'txId': 7226,
#                 'username': 'neo4j'},
#     'payload': {   'after': None,
#                    'before': {   'labels': ['User'],
#                                  'properties': {   'bio': 'Penetration Test & '
#                                                           'Security Research '
#                                                           'company based on '
#                                                           'Istanbul, Turkey.',
#                                                    'followers': 1317,
#                                                    'following': 16,
#                                                    'id': 179118223,
#                                                    'location': 'Istanbul, '
#                                                                'Turkey',
#                                                    'name': 'ADEO Security Labs',
#                                                    'tweets': 189,
#                                                    'username': 'adeosecurity'}},
#                    'id': '5568',
#                    'type': 'node'},
#     'schema': {'constraints': None, 'properties': []}}
# {   'meta': {   'operation': 'deleted',
#                 'source': {'hostname': 'neo4j'},
#                 'timestamp': 1558278302233,
#                 'txEventId': 16,
#                 'txEventsCount': 27,
#                 'txId': 7226,
#                 'username': 'neo4j'},
#     'payload': {   'after': None,
#                    'before': {   'labels': ['User'],
#                                  'properties': {   'id': 892256485,
#                                                    'username': 'neoquestions'}},
#                    'id': '5569',
#                    'type': 'node'},
#     'schema': {'constraints': None, 'properties': []}}
# {   'meta': {   'operation': 'created',
#                 'source': {'hostname': 'neo4j'},
#                 'timestamp': 1558278316512,
#                 'txEventId': 1,
#                 'txEventsCount': 3,
#                 'txId': 7227,
#                 'username': ''},
#     'payload': {   'after': {   'labels': ['User'],
#                                 'properties': {   'id': 599665849,
#                                                   'username': 'graphconnect'}},
#                    'before': None,
#                    'id': '5537',
#                    'type': 'node'},
#     'schema': {'constraints': None, 'properties': []}}
# {   'meta': {   'operation': 'created',
#                 'source': {'hostname': 'neo4j'},
#                 'timestamp': 1558278316525,
#                 'txEventId': 0,
#                 'txEventsCount': 3,
#                 'txId': 7228,
#                 'username': ''},
#     'payload': {   'after': {   'labels': ['User'],
#                                 'properties': {   'id': 13500752,
#                                                   'username': 'nuraini'}},
#                    'before': None,
#                    'id': '5557',
#                    'type': 'node'},
#     'schema': {'constraints': None, 'properties': []}}
# {   'meta': {   'operation': 'created',
#                 'source': {'hostname': 'neo4j'},
#                 'timestamp': 1558278316559,
#                 'txEventId': 0,
#                 'txEventsCount': 21,
#                 'txId': 7229,
#                 'username': ''},
#     'payload': {   'after': {   'labels': ['User'],
#                                 'properties': {   'id': 703296564,
#                                                   'username': 'neo4jfr'}},
#                    'before': None,
#                    'id': '5570',
#                    'type': 'node'},
#     'schema': {'constraints': None, 'properties': []}}
# {   'meta': {   'operation': 'created',
#                 'source': {'hostname': 'neo4j'},
#                 'timestamp': 1558278316559,
#                 'txEventId': 1,
#                 'txEventsCount': 21,
#                 'txId': 7229,
#                 'username': ''},
#     'payload': {   'after': {   'labels': ['User'],
#                                 'properties': {   'id': 179118223,
#                                                   'username': 'adeosecurity'}},
#                    'before': None,
#                    'id': '5568',
#                    'type': 'node'},
#     'schema': {'constraints': None, 'properties': []}}
# {   'meta': {   'operation': 'created',
#                 'source': {'hostname': 'neo4j'},
#                 'timestamp': 1558278316559,
#                 'txEventId': 3,
#                 'txEventsCount': 21,
#                 'txId': 7229,
#                 'username': ''},
#     'payload': {   'after': {   'labels': ['User'],
#                                 'properties': {   'id': 892256485,
#                                                   'username': 'neoquestions'}},
#                    'before': None,
#                    'id': '5569',
#                    'type': 'node'},
#     'schema': {'constraints': None, 'properties': []}}
# {   'meta': {   'operation': 'created',
#                 'source': {'hostname': 'neo4j'},
#                 'timestamp': 1558278316559,
#                 'txEventId': 11,
#                 'txEventsCount': 21,
#                 'txId': 7229,
#                 'username': ''},
#     'payload': {   'after': {   'labels': ['User'],
#                                 'properties': {   'id': 18263413,
#                                                   'username': 'rvanbruggen'}},
#                    'before': None,
#                    'id': '5567',
#                    'type': 'node'},
#     'schema': {'constraints': None, 'properties': []}}
# {   'meta': {   'operation': 'created',
#                 'source': {'hostname': 'neo4j'},
#                 'timestamp': 1558278316559,
#                 'txEventId': 12,
#                 'txEventsCount': 21,
#                 'txId': 7229,
#                 'username': ''},
#     'payload': {   'after': {   'labels': ['User'],
#                                 'properties': {   'id': 22467617,
#                                                   'username': 'neo4j'}},
#                    'before': None,
#                    'id': '5566',
#                    'type': 'node'},
#     'schema': {'constraints': None, 'properties': []}}

# %%
# Events on this topic are filtered by KSQL
consumer = KafkaConsumer("USERS2_CREATED", 
                         auto_offset_reset='earliest',
                         bootstrap_servers=[kafka_broker], 
                         api_version=(0, 10),                     
                         consumer_timeout_ms=1000,
                        value_deserializer = json.loads)

for msg in consumer:
    document = msg.value
    
    c = twint.Config()
    c.Username = document["PAYLOAD"]["AFTER"]["properties"]["username"]
    c.Store_json = False
    c.User_full = True
    c.Store_object = True
    c.Hide_output = True

    twint.run.Lookup(c)
    
    user = twint.output.user_object[0].__dict__
    print(user["username"], user)
    
    publish_message(kafka_producer, "users_enriched", user["name"], json.dumps(user))
    
    twint.output.user_object = []
# Out:
# rvanbruggen {'id': '18263413', 'name': 'Rik Van Bruggen', 'username': 'rvanbruggen', 'bio': 'Mad about graphs. Working on and with Neo4j. Write about that on http://blog.bruggen.com\xa0.', 'location': 'Antwerp', 'url': 'http://www.neo4j.com', 'join_date': '19 Dec 2008', 'join_time': '11:43 PM', 'tweets': 3402, 'following': 1176, 'followers': 2010, 'likes': 3978, 'media_count': 545, 'is_private': 0, 'is_verified': 0, 'avatar': 'https://pbs.twimg.com/profile_images/799599347633684481/IdlOGInc_400x400.jpg', 'background_image': 'https://pbs.twimg.com/profile_banners/18263413/1383756105/1500x500'}
# Message published successfully.
# GraphConnect {'id': '599665849', 'name': 'GraphConnect', 'username': 'GraphConnect', 'bio': 'The largest global gathering of graph technology experts and enthusiasts.', 'location': '', 'url': 'http://graphconnect.com', 'join_date': '4 Jun 2012', 'join_time': '4:50 PM', 'tweets': 5251, 'following': 2627, 'followers': 4884, 'likes': 1419, 'media_count': 1479, 'is_private': 0, 'is_verified': 0, 'avatar': 'https://pbs.twimg.com/profile_images/850442698217603072/qI3NBTum_400x400.jpg', 'background_image': 'https://pbs.twimg.com/profile_banners/599665849/1532621637/1500x500'}
# Message published successfully.
# Neo4jFr {'id': '703296564', 'name': 'Neo4j France', 'username': 'Neo4jFr', 'bio': "Neo4j est une base de données NoSql qui répond au défi des données complexes fortement connectées que les entreprises rencontrent aujourd'hui.", 'location': 'Paris, France', 'url': 'http://www.neo4j.com', 'join_date': '18 Jul 2012', 'join_time': '8:43 AM', 'tweets': 3904, 'following': 186, 'followers': 985, 'likes': 449, 'media_count': 1117, 'is_private': 0, 'is_verified': 0, 'avatar': 'https://pbs.twimg.com/profile_images/615835011141496832/Du9-iHRg_400x400.png', 'background_image': 'https://pbs.twimg.com/profile_banners/703296564/1525863765/1500x500'}
# Message published successfully.
# adeosecurity {'id': '179118223', 'name': 'ADEO Security Labs', 'username': 'adeosecurity', 'bio': 'Penetration Test & Security Research company based on Istanbul, Turkey.', 'location': 'Istanbul, Turkey', 'url': 'http://www.adeosecurity.com', 'join_date': '16 Aug 2010', 'join_time': '8:12 AM', 'tweets': 189, 'following': 16, 'followers': 1317, 'likes': 60, 'media_count': 25, 'is_private': 0, 'is_verified': 0, 'avatar': 'https://pbs.twimg.com/profile_images/735090806583918592/VveQ-DOE_400x400.jpg', 'background_image': 'https://pbs.twimg.com/profile_banners/179118223/1464094491/1500x500'}
# Message published successfully.
# neo4j {'id': '22467617', 'name': 'Neo4j', 'username': 'neo4j', 'bio': 'The #1 platform for connected data. Developers start here: https://neo4j.com/developer/\xa0', 'location': 'Graphs Are Everywhere', 'url': 'https://neo4j.com/', 'join_date': '2 Mar 2009', 'join_time': '12:59 AM', 'tweets': 40050, 'following': 7243, 'followers': 28692, 'likes': 10954, 'media_count': 9033, 'is_private': 0, 'is_verified': 1, 'avatar': 'https://pbs.twimg.com/profile_images/880015248324837376/rsuw4VRB_400x400.jpg', 'background_image': 'https://pbs.twimg.com/profile_banners/22467617/1555368872/1500x500'}
# Message published successfully.
# nuraini {'id': '13500752', 'name': 'Nur Aini Rakhmawati', 'username': 'nuraini', 'bio': 'a geek mother of two girls   hold aaPhD from @INSIGHT_Centre  Galway @yordangunawan wife works @its_campus', 'location': 'Galway, Ireland', 'url': 'http://ai23.wordpress.com', 'join_date': '14 Feb 2008', 'join_time': '6:34 PM', 'tweets': 17830, 'following': 197, 'followers': 2570, 'likes': 170, 'media_count': 275, 'is_private': 0, 'is_verified': 0, 'avatar': 'https://pbs.twimg.com/profile_images/3370361650/59af2b39664d3153e2d7da1cb5f8c021_400x400.jpeg', 'background_image': None}
# Message published successfully.
# NeoQuestions {'id': '892256485', 'name': 'Neo Questions', 'username': 'NeoQuestions', 'bio': 'Stackoverflow questions about #Neo4j. Maintained by @wefreema.', 'location': '', 'url': None, 'join_date': '19 Oct 2012', 'join_time': '7:00 PM', 'tweets': 15396, 'following': 0, 'followers': 216, 'likes': 1, 'media_count': 0, 'is_private': 0, 'is_verified': 0, 'avatar': 'https://pbs.twimg.com/profile_images/2741457908/3400440ef574e61c4d812422d23e42dc_400x400.png', 'background_image': 'https://pbs.twimg.com/profile_banners/892256485/1350951513/1500x500'}
# Message published successfully.

# %%
# Events on this topic are filtered by KSQL
consumer = KafkaConsumer("USERS2_CREATED", 
                         auto_offset_reset='earliest',
                         bootstrap_servers=[kafka_broker], 
                         api_version=(0, 10),                     
                         consumer_timeout_ms=1000,
                        value_deserializer = json.loads)

for msg in consumer:
    document = msg.value
    username = document["PAYLOAD"]["AFTER"]["properties"]["username"]
    print(username)
    
    c = twint.Config()
    c.Username = username
    c.User_full = False
    c.Store_object = True
    c.Hide_output = True

    twint.run.Followers(c)
    followers = twint.output.follow_object

    if not username in followers:
        followers[username] = {"followers": []}
    
    user = {"followers": followers[username]["followers"], "username": username}
    
    publish_message(kafka_producer, "followers", username, json.dumps(user))
    
    twint.output.follow_object = {}

# %%
# Events on this topic are filtered by KSQL
consumer = KafkaConsumer("USERS2_CREATED", 
                         auto_offset_reset='earliest',
                         bootstrap_servers=[kafka_broker], 
                         api_version=(0, 10),                     
                         consumer_timeout_ms=1000,
                        value_deserializer = json.loads)

for msg in consumer:
    document = msg.value
    username = document["PAYLOAD"]["AFTER"]["properties"]["username"]
    print(username)
    
    c = twint.Config()
    c.Username = username
    c.User_full = False
    c.Store_object = True
    c.Hide_output = True

    twint.run.Following(c)
    following = twint.output.follow_object

    if not username in following:
        following[username] = {"following": []}
    
    user = {"following": following[username]["following"], "username": username}
    
    publish_message(kafka_producer, "following", username, json.dumps(user))
    
    twint.output.follow_object = {}
